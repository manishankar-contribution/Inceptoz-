# %%
import pandas as pd
import numpy as np

# %%
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

# %%
df=pd.DataFrame(exam_data,index=['a','b','c','d','e','f','g','h','i','j'])
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.loc['d','score']=11.5
#df.iat[]
#df.at
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df[(df.score > 15) & (df.attempts < 2)]
# Out:
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %%
df.loc[df.index =='d','score']=11.5
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#pleae don't consider this cell, just for my reference
print(df.loc['b']['name'])

print(df['name']['b'])

print(df['b']['name'])
# Out:
# Dima
# Dima
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'b'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-c80343e93c8c> in <module>
#       1 print(df.loc['b']['name'])
# ...

# %%
data = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}

d=pd.DataFrame(data)
print('ord df','\n',d)

d[d['col1'] == 4]
# Out:
# ord df
#     col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
#    col1  col2  col3
# 1     4     5     8
# 3     4     7     0

# %%
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
ddf=pd.DataFrame(d)
print(ddf)
print('removing rows')
ddf.drop([2,4])
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# removing rows
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 3     4     7     0

# %%
q=ddf.columns
x=input("enter the column name to check for exist :")
if x in q:
    print (x, ' is present in dataframe')
else:
    print (x, ' is not present in dataframe')
# Out:
# enter the column name to check for exist :col3
# col3  is present in dataframe

# %%
ddf.columns.get_loc('col2')
# Out:
# 1

# %%
d_cols=[x for x in ddf.columns if x != 'col3']
ddf[d_cols]
# Out:
#    col1  col2
# 0     1     4
# 1     4     5
# 2     3     6
# 3     4     7
# 4     5     8

# %%
#ddf.drop([ddf.index > 2])
df2=ddf.iloc[:3]
df2
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptz-Batch13-Analytics_and_Python/master/05%20-%20Day%205%20-%20Pandas%20with%20Exercises/IMDB-Movie-Data.csv')

# %%
df[(df['Runtime (Minutes)'] > 30) & (df['Runtime (Minutes)'] < 150)] [['Title','Runtime (Minutes)']]
# Out:
#                        Title  Runtime (Minutes)
# 0    Guardians of the Galaxy                121
# 1                 Prometheus                124
# 2                      Split                117
# 3                       Sing                108
# 4              Suicide Squad                123
# ..                       ...                ...
# 995     Secret in Their Eyes                111
# 996          Hostel: Part II                 94
# 997   Step Up 2: The Streets                 98
# 998             Search Party                 93
# 999               Nine Lives                 87
#
# [949 rows x 2 columns]

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
